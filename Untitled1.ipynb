# %%
import pprint
import nidaqmx

pp = pprint.PrettyPrinter(indent=4)


with nidaqmx.Task() as task:
    task.ai_channels.add_ai_voltage_chan("Dev1/ai0")

    # Setea la frecuencia de muestrreo
    task.timing.cfg_samp_clk_timing(1000)

    # Python 2.X does not have nonlocal keyword.
    non_local_var = {'samples': []}

    def callback(task_handle, every_n_samples_event_type,
                 number_of_samples, callback_data):
        print('Every N Samples callback invoked.')

        samples = task.read(number_of_samples_per_channel=200)
        non_local_var['samples'].extend(samples)

        return 0

    task.register_every_n_samples_acquired_into_buffer_event(
        200, callback)

    task.start()

    input('Running task. Press Enter to stop and see number of '
          'accumulated samples.\n')

    print(len(non_local_var['samples']))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-ab2a6f59407d> in <module>()
#       5
#       6
# ----> 7 with nidaqmx.Task() as task:
#       8     task.ai_channels.add_ai_voltage_chan("Dev1/ai0")
#       9
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\task.py in __init__(self, new_task_name)
#      82                 results in an error.
#      83         """
# ---> 84         self._handle = lib_importer.task_handle(0)
#      85
#      86         cfunc = lib_importer.windll.DAQmxCreateTask
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in task_handle(self)
#     176     def task_handle(self):
#     177         if self._task_handle is None:
# --> 178             self._parse_typedefs()
#     179         return self._task_handle
#     180
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _parse_typedefs(self)
#     239         # If DAQmx 8.8 and lower, TaskHandle is a typedef for uInt32 since
#     240         # DAQmx didn't support 64-bit applications then.
# --> 241         version = system.driver_version
#     242         if version.major_version <= 8 and version.minor_version <= 8:
#     243             self._task_handle = ctypes.c_uint
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in driver_version(self)
#      71                               'update_version'])
#      72
# ---> 73         return DriverVersion(self._major_version, self._minor_version,
#      74                              self._update_version)
#      75
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in _major_version(self)
#     106         val = ctypes.c_uint()
#     107
# --> 108         cfunc = lib_importer.windll.DAQmxGetSysNIDAQMajorVersion
#     109         if cfunc.argtypes is None:
#     110             with cfunc.arglock:
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in windll(self)
#     164     def windll(self):
#     165         if self._windll is None:
# --> 166             self._import_lib()
#     167         return self._windll
#     168
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _import_lib(self)
#     207                 cdll = ctypes.cdll.nicaiu
#     208             else:
# --> 209                 windll = ctypes.windll.LoadLibrary(lib_name)
#     210                 cdll = ctypes.cdll.LoadLibrary(lib_name)
#     211
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in LoadLibrary(self, name)
#     424
#     425     def LoadLibrary(self, name):
# --> 426         return self._dlltype(name)
#     427
#     428 cdll = LibraryLoader(CDLL)
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: [WinError 126] No se puede encontrar el módulo especificado

# %%
import pprint
import nidaqmx

pp = pprint.PrettyPrinter(indent=4)

with nidaqmx.Task() as task:
    task.ai_channels.add_ai_voltage_chan("cDAQ1Mod1/ai0")

    print('1 Channel 1 Sample Read Raw: ')
    data = task.read_raw()
    pp.pprint(data)

    print('1 Channel N Samples Read Raw: ')
    data = task.read_raw(number_of_samples_per_channel=8)
    pp.pprint(data)

    task.ai_channels.add_ai_voltage_chan("cDAQ1Mod1/ai1:3")

    print('N Channel 1 Sample Read Raw: ')
    data = task.read_raw()
    pp.pprint(data)

    print('N Channel N Samples Read Raw: ')
    data = task.read_raw(number_of_samples_per_channel=8)
    pp.pprint(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-70ff68984c9d> in <module>()
#       4 pp = pprint.PrettyPrinter(indent=4)
#       5
# ----> 6 with nidaqmx.Task() as task:
#       7     task.ai_channels.add_ai_voltage_chan("cDAQ1Mod1/ai0")
#       8
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\task.py in __init__(self, new_task_name)
#      82                 results in an error.
#      83         """
# ---> 84         self._handle = lib_importer.task_handle(0)
#      85
#      86         cfunc = lib_importer.windll.DAQmxCreateTask
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in task_handle(self)
#     176     def task_handle(self):
#     177         if self._task_handle is None:
# --> 178             self._parse_typedefs()
#     179         return self._task_handle
#     180
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _parse_typedefs(self)
#     239         # If DAQmx 8.8 and lower, TaskHandle is a typedef for uInt32 since
#     240         # DAQmx didn't support 64-bit applications then.
# --> 241         version = system.driver_version
#     242         if version.major_version <= 8 and version.minor_version <= 8:
#     243             self._task_handle = ctypes.c_uint
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in driver_version(self)
#      71                               'update_version'])
#      72
# ---> 73         return DriverVersion(self._major_version, self._minor_version,
#      74                              self._update_version)
#      75
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in _major_version(self)
#     106         val = ctypes.c_uint()
#     107
# --> 108         cfunc = lib_importer.windll.DAQmxGetSysNIDAQMajorVersion
#     109         if cfunc.argtypes is None:
#     110             with cfunc.arglock:
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in windll(self)
#     164     def windll(self):
#     165         if self._windll is None:
# --> 166             self._import_lib()
#     167         return self._windll
#     168
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _import_lib(self)
#     207                 cdll = ctypes.cdll.nicaiu
#     208             else:
# --> 209                 windll = ctypes.windll.LoadLibrary(lib_name)
#     210                 cdll = ctypes.cdll.LoadLibrary(lib_name)
#     211
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in LoadLibrary(self, name)
#     424
#     425     def LoadLibrary(self, name):
# --> 426         return self._dlltype(name)
#     427
#     428 cdll = LibraryLoader(CDLL)
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: [WinError 126] No se puede encontrar el módulo especificado

# %%
nidaqmx.Task()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-820ad2f92c97> in <module>()
# ----> 1 nidaqmx.Task()
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\task.py in __init__(self, new_task_name)
#      82                 results in an error.
#      83         """
# ---> 84         self._handle = lib_importer.task_handle(0)
#      85
#      86         cfunc = lib_importer.windll.DAQmxCreateTask
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in task_handle(self)
#     176     def task_handle(self):
#     177         if self._task_handle is None:
# --> 178             self._parse_typedefs()
#     179         return self._task_handle
#     180
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _parse_typedefs(self)
#     239         # If DAQmx 8.8 and lower, TaskHandle is a typedef for uInt32 since
#     240         # DAQmx didn't support 64-bit applications then.
# --> 241         version = system.driver_version
#     242         if version.major_version <= 8 and version.minor_version <= 8:
#     243             self._task_handle = ctypes.c_uint
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in driver_version(self)
#      71                               'update_version'])
#      72
# ---> 73         return DriverVersion(self._major_version, self._minor_version,
#      74                              self._update_version)
#      75
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\system\system.py in _major_version(self)
#     106         val = ctypes.c_uint()
#     107
# --> 108         cfunc = lib_importer.windll.DAQmxGetSysNIDAQMajorVersion
#     109         if cfunc.argtypes is None:
#     110             with cfunc.arglock:
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in windll(self)
#     164     def windll(self):
#     165         if self._windll is None:
# --> 166             self._import_lib()
#     167         return self._windll
#     168
#
# ~\Anaconda3\envs\py36\lib\site-packages\nidaqmx\_lib.py in _import_lib(self)
#     207                 cdll = ctypes.cdll.nicaiu
#     208             else:
# --> 209                 windll = ctypes.windll.LoadLibrary(lib_name)
#     210                 cdll = ctypes.cdll.LoadLibrary(lib_name)
#     211
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in LoadLibrary(self, name)
#     424
#     425     def LoadLibrary(self, name):
# --> 426         return self._dlltype(name)
#     427
#     428 cdll = LibraryLoader(CDLL)
#
# ~\Anaconda3\envs\py36\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: [WinError 126] No se puede encontrar el módulo especificado
